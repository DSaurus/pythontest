# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt("C:/Users/sao/Desktop/spectrum.txt")
print(data)
l = [0 for x in range(0, 20)]
for i in range(0, 200):
    l[i//10] += data[i]
print(l)
plt.plot(range(0, 20), l, 'b-')
#data = np.loadtxt("C:/Users/sao/Desktop/s.txt")
#plt.plot(range(0, 1024), data, 'r-')
plt.show()
# Out:
# [  3.70724000e-03   2.22859000e-02   4.35060000e-02 ...,   5.12143000e-08
#    1.58724000e-07   6.90745000e-08]
# [0.29158139, 0.30425501000000005, 0.23394670999999995, 0.057633022999999999, 0.12381162, 0.045583739999999991, 0.16818535299999998, 0.053568563999999999, 0.018808739999999997, 0.048725337000000007, 0.017585360000000001, 0.014231351999999999, 0.0090953700000000002, 0.016132519999999997, 0.0085827785000000007, 0.0092167639999999988, 0.009388123, 0.0041300534, 0.009176285000000001, 0.0063572250000000002]
