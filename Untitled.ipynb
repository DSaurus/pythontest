# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt("E:/forjianmo/dataVMOS.txt")
x = data[:, 2]
y = data[:, 0]
l = []
for _ in range(300, 501):
    a = [t for t in data if t[3] == _/100]
    if len(a) < 6:
        continue
    a = np.array(a)
    #print(a)
    f = np.poly1d(np.polyfit(a[:, 2], a[:, 0], 3))
    X = np.linspace(1, 5, 100)
    #plt.plot(X, f(X), 'r-')
    l.append(np.polyfit(a[:, 2], a[:, 0], 3))
plt.plot(range(0, len(l)), np.array(l)[:, 0], '.'
print(l)
plt.show()
# Out:
# [array([ 0.03122307, -0.38489475,  2.04076078, -1.08470881]), array([ 0.00793747, -0.1647532 ,  1.36336409, -0.38245853]), array([-0.02993638,  0.15939803,  0.47944634,  0.39095854]), array([ 0.02297295, -0.31342611,  1.84290793, -0.81978464]), array([ 0.02613957, -0.34062272,  1.91872801, -0.87180519]), array([ 0.03008062, -0.38878233,  2.09672962, -1.0500593 ]), array([ 0.03092989, -0.38309204,  2.03663645, -0.93588115]), array([ 0.02798924, -0.36167513,  1.99091353, -0.89577498]), array([-0.01840261,  0.03331923,  0.90111536,  0.08276171]), array([-0.01884907,  0.01894882,  0.96887993,  0.03096277]), array([-0.0012708 , -0.09015429,  1.18098611, -0.09032411]), array([ 0.02177435, -0.30605186,  1.83120673, -0.7037121 ]), array([ 0.03676251, -0.41528574,  2.08460231, -0.87744066]), array([ 0.02938533, -0.36578355,  1.97525764, -0.78226323]), array([ 0.02288441, -0.31743066,  1.86849416, -0.70161916]), array([ 0.02546509, -0.3312537 ,  1.87620156, -0.6592954 ]), array([ 0.02635137, -
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt("E:/forjianmo/dataVMOS.txt")
print(data.shape)
data = np.array([x for x in data if x[1] == 4.33])
x = data[:, 2] + data[:, 3]
y = data[:, 2]*data[:, 3]
z = data[:, 0]
print(x)
print(y)
print(z)
print(np.mean(x))
a = [y[i] for i in range(0, 59503) if x[i] == 8.9]
b = [z[i] for i in range(0, 59503) if x[i] == 8.9]

plt.plot(a, b, 'b.')
plt.show()
# Out:
# (89266, 4)
# [ 9.04  9.05  9.08 ...,  9.21  9.29  8.51]
# [ 20.2   20.25  20.4  ...,  21.05  21.45  17.55]
# [ 3.96  3.96  3.98 ...,  4.03  4.06  3.72]
# 8.76156731593

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt("E:/forjianmo/dataVMOS.txt")
print(data.shape)
data = np.array([x for x in data if (x[0] >= 4 and x[0] <= 4.1) and x[1] == 4.33])
print(data)
plt.plot(4, 6, '.')
plt.plot(data[:, 2], data[:, 3], '.')
plt.show()
# Out:
# (89266, 4)
# [[ 4.    4.33  4.14  5.  ]
#  [ 4.02  4.33  4.18  5.  ]
#  [ 4.    4.33  4.13  5.  ]
#  ...,
#  [ 4.01  4.33  4.16  5.  ]
#  [ 4.03  4.33  4.21  5.  ]
#  [ 4.06  4.33  4.29  5.  ]]
